# %%
import pandas as pd
import pylab as pl
import seaborn as sns
from scipy import stats

from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np
from sklearn.datasets import load_boston
#import statsmodels.api as sm
from sklearn.svm import SVR

pd.set_option('precision', 3)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
sns.set(font_scale=1) # размер шрифта

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv('../py2019/var27/whitewines.csv', # путь к файлу, используй автодотолнение
                   sep=',', # разделитель данных в файле
                   header=0 # номер строки с заголовками. header='None', если заголовки отсутствуют
                  )

# %%
data [0:2]
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          7.000             0.270        0.360          20.700      0.045
# 1          6.300             0.300        0.340           1.600      0.049
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0               45.000               170.000    1.001 3.000      0.450
# 1               14.000               132.000    0.994 3.300      0.490
#
#    alcohol  quality
# 0    8.800        6
# 1    9.500        6

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
# fixed acidity           4898 non-null float64
# volatile acidity        4898 non-null float64
# citric acid             4898 non-null float64
# residual sugar          4898 non-null float64
# chlorides               4898 non-null float64
# free sulfur dioxide     4898 non-null float64
# total sulfur dioxide    4898 non-null float64
# density                 4898 non-null float64
# pH                      4898 non-null float64
# sulphates               4898 non-null float64
# alcohol                 4898 non-null float64
# quality                 4898 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 459.2 KB
# None

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# # 1.Результаты первичного анализа исходных данных

# %% [markdown]
# # 1.1 Количество записей и признаков

# %%
nrow = data.shape[0]
ncol = data.shape[1]
print ("Итого: " + str(nrow) + " записи, " + str(ncol) + " столбец (признак).")
# Out:
# Итого: 4898 записи, 12 столбец (признак).

# %% [markdown]
# # 1.2 Смысловое описание признаков

# %%
data[:1]
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          7.000             0.270        0.360          20.700      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0               45.000               170.000    1.001 3.000      0.450
#
#    alcohol  quality
# 0    8.800        6

# %% [markdown]
# Данные "whitewines" содержат информацию о характеристиках белого вина
#  - fixed acidity: фиксированная кислотность
#  - volatile acidity: летучая кислотность
#  - citric acid: лимонная кислота
#  - residual sugar: остаточный сахар
#  - chlorides: хлориды
#  - free sulfur dioxide: свободный диоксид серы
#  - total sulfur dioxide: диоксид серы
#  - density: плотность
#  - pH: степень кислотности
#  - sulphates: сульфаты
#  - alcohol: процент содержания спирта в напитке
#  - quality: качество (от 1 до 10)

# %% [markdown]
# # 1.3  Типы данных столбцов и информация о пропусках

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
# fixed acidity           4898 non-null float64
# volatile acidity        4898 non-null float64
# citric acid             4898 non-null float64
# residual sugar          4898 non-null float64
# chlorides               4898 non-null float64
# free sulfur dioxide     4898 non-null float64
# total sulfur dioxide    4898 non-null float64
# density                 4898 non-null float64
# pH                      4898 non-null float64
# sulphates               4898 non-null float64
# alcohol                 4898 non-null float64
# quality                 4898 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 459.2 KB
# None

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# Пропусков нет

# %% [markdown]
# # 1.4 Результат замены категориальных или ранговых данных на числовые

# %% [markdown]
# Не требуется, т.к. все данные присутствуют, и приведены в числовом формате

# %% [markdown]
# # 1.5 Результат обработки пропущенных значений

# %% [markdown]
# Пропущенных значений нет

# %% [markdown]
# # 2.Обоснование выбора целевой переменной и признаков для анализа

# %% [markdown]
# # 2.1 Перечень вариантов целевых переменных, исходя из п. 1.2.

# %% [markdown]
# Согласно пункту 1.2 целевыми параметрами выбрали quality(качество, оценка), alcohol(содержание спиртов),density(плотность)

# %% [markdown]
# # 2.2 Матрица коэффициентов корреляции

# %%
corrdf = data.corr(method='spearman')
sns.set(style="white")# цвет фона

# построить "маску" для отображения только половины корреляционной матрицы
mask = np.zeros_like(corrdf, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

fig, ax = plt.subplots(figsize=(9,9))
sns.set(font_scale=0.8) # размер шрифта

# Построить тепловую карту
sns.heatmap(data=corrdf, vmin=-1, vmax=1, center=0,
            annot=True, 
            cmap = 'RdBu',
            mask=mask,   # применить маску
            square=True, # форма ячейки - квадрат
            linewidths=1.0, # зазор между ячейки
            #cbar_kws={"shrink": .5}  # уменьшить размер легенды
           )
plt.title(u'Матрица корреляции признаков');

# %% [markdown]
# На основе информации о взаимозависимости и степени влияния признаков выбрали целевое значение
# - quality (качество, оценка)
#
# поскольку на неё влияют ряд параметров
#
# - density(плотность)(чем меньше, тем лучше качество),
# - chlorides(содержание хлоридов)(чем меньше, тем лучше качество),
# - alcohol(содержание спирта)(чем больше, тем лучше качество).
#
# Эти параметры выбюираем в качестве влияющих

# %% [markdown]
# # 2.3 Матрица смежности (графический вариант интерпретации взаимосвязей переменных)

# %%
# %config InlineBackend.figure_format = 'png' # формат изображений PNG, для сокращения времени отрисовки графиков       
sns.pairplot(data)
